# %% [markdown]
# # Upload Images

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow_datasets as tfds

import os
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output

tfds.disable_progress_bar()
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
# !ls

# %%
# !pip install PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':"1u6SO_pwe5KeP0FXRcW4mk_e4LEPr-zhz"})   # replace the id with id of file you want to access
data=downloaded.GetContentFile('screenshotsSimulator.zip')        # replace the file name with your file

# %%
downloaded = drive.CreateFile({'id':"1F0c5MeQHb5teQTGXFfIYwEqrFcfF3104"})   # replace the id with id of file you want to access
downloaded.GetContentFile('ScreenshotsRealImages.zip')        # replace the file name with your file

# %%
# !ls

# %%
# !unzip screenshotsSimulator.zip

# %%
# !unzip ScreenshotsRealImages.zip

# %%
from IPython.display import Image
Image("screenshotsSimulator/scene00001.png", width=300)

# %%
Image("ScreenshotsRealImages/scene00851.png", width=300)

# %% [markdown]
# ## Import and reuse the Pix2Pix models

# %%
import glob
simImages = glob.glob('/content/screenshotsSimulator' + '/*.png')
realImages= glob.glob('/content/ScreenshotsRealImages' + '/*.png')

# %%
import numpy as np
simImages=np.array(simImages)
print(simImages.shape)
Image(simImages[2], width=300)

# %%
realImages=np.array(realImages)
Image(realImages[67], width=300)

# %%
from PIL import Image

def get_num_pixels(filepath):
    width, height = Image.open(filepath).size
    return (width,height)

print('RealImages pixel size:', get_num_pixels(realImages[0]))

# %%
print('SimImages pixel size:', get_num_pixels(simImages[0]))

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix.git

# %%
from cycleGANProject.data.base_dataset import BaseDataset

# %%
from data.base_dataset import BaseDataset, get_transform

# %% [markdown]
# #Preprocess Images
# Inspired by https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/data/template_dataset.py

# %%
from data.base_dataset import BaseDataset

# %%
# !ls

# %%
downloaded = drive.CreateFile({'id':"19bzVg4jrxyaVVAKHJyclUrHHrSNAI5l3"})   # replace the id with id of file you want to access
downloaded.GetContentFile('data')

# %%
# %cd cycleGANProject/

# %%
# !python test.py
